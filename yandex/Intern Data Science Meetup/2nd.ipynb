# %% [markdown]
# https://contest.yandex.ru/contest/47729/problems/B/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Решение не сохранилось, однако оно заключается в применении CatBoost относительно сырых данных. Данный подход не является креативным, однако в момент соревнования основная задача - получить как можно больше баллов.
